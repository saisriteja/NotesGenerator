# %% [markdown]
# # NotesGenerator
#
# GPU runtime required (Runtime → Change runtime type → T4 GPU).

# %%
# !pip install -q "git+https://github.com/saisritejakuppaEros/NotesGenerator.git#subdirectory=note_taker[gpu]"
# !apt-get install -y -qq ffmpeg libsm6 libxext6 libgl1

# %%
from notesgenerator.colab_env import configure_colab_env
configure_colab_env()

# %%
from google.colab import files
uploaded = files.upload()
VIDEO_PATH = "/content/" + list(uploaded.keys())[0]

# %%
OUTPUT_NAME = "my_lecture"
# !notesgenerator --video "{VIDEO_PATH}" --output {OUTPUT_NAME}

# %%
from IPython.display import Markdown, display
from pathlib import Path
display(Markdown((Path("runs") / OUTPUT_NAME / "report" / "report.md").read_text()))
